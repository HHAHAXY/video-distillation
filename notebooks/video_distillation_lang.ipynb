# %%
import numpy as np
import whisper
PATH2VID = "/Users/rusiq/Downloads/youtube_dl/katka1_5min.mp4"

# %%
model = whisper.load_model("turbo")
# Out:
# 100%|█████████████████████████████████████| 1.51G/1.51G [04:02<00:00, 6.67MiB/s]

# %%
out = model.transcribe(PATH2VID, language="russian")
print(out['text'])
# Out:
# /usr/local/Caskroom/miniconda/base/envs/whisper/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
print(out['text'][0:10000])
# Out:
#  Против коллапса попался. Блядь, сегодня, короче, походу придется отъебать всю команду Team Spirit. У Етора мы уже ПТСы забрали, выебли. Теперь против коллапса, ребят. Против коллапса ебашить будем. Ну, сейчас разъебу молодого, а что? В UFC я его уже ебальничек разбил на Бэтбумдаче в Дубае. Теперь пора и в дотке ПТСки забрать. Так что, ребят, против коллапса играем. Нахуй. Все, показываю вам экранчик. Коллапс на Миране. Вот. И это первая страница, ребят. Вот что значит средний рейд 11 тысяч. Вот мы уже почти подошли к 11 косарикам, и дота стала такой, знаете, уже про игроки в каждой второй игре, плюс-минус. То есть, как бы, даже сопротивляться начали из хороших новостей. Вот. Поэтому поехали. Поехали бить ебальники. Ну, вы знаете, я на сигнатурке. Я на сигнатурке. Я на сигнатурочке ебашу. На Огре ебать. Вы знаете, что если Олежа выкатывается на Огре, это пиздец. Прячься, нахуй. Кстати, у меня на Миде... Здорово, усатый тут он хамон. Сам такой ебать, нахуй. Что ты выебываешься там на 
# ...
